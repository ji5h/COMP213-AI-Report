# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
root = '/content/gdrive/My Drive/Rock Paper Scissors Detection/Rock Paper Scissors.v44-rock-paper-scissors_raw-images.yolov8'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO
# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
# Use the model
model.train(data= os.path.join(root,'data.yaml') , epochs=500,batch=-1,patience=500)  # train the model
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !scp -r /content/runs '/content/gdrive/My Drive/Rock Paper Scissors Detection'
